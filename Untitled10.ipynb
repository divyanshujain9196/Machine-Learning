# %%
import pandas as pd

# %%
data = pd.read_csv('Student_dataset.csv')

# %%
data
# Out:
#    id       Name Course  Age  Subject1  Subject2  Subject3  Subject4  Total  \
# 0   1    Atishay  BTECH   19        97        90        98        78    363
# 1   2  Divyanshu  BTECH   20        98        76        99        98    371
# 2   3       Aman    BSC   19        97        56        98        78    329
# 3   4        Ram    BCA   19        70        97        78        87    332
# 4   5      Shyam     BA   20        69        86        98        78    331
# 5   6     Aviral    BBA   21        96        87        78        87    348
# 6   7    Saksham    LLB   20        85        84        68        78    315
# 7   8     Pranav   MBBS   21        92        92        98        78    360
# 8   9     Aakash    MBA   23        70        69        87        98    324
#
#    Percentage Grade
# 0       90.75     A
# 1       92.75     A
# 2       82.25     B
# 3       83.00     B
# 4       82.75     B
# 5       87.00     B
# 6       78.75     B
# 7       90.00     B
# ...
